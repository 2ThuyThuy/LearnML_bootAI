# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer

from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans 

from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
from yellowbrick.cluster import KElbowVisualizer

from sklearn_som.som import SOM
RAND = 24

# %%
dataset = pd.read_csv('data.csv')
dataset.describe().T
# Out:
#         count          mean           std       min           25%  \
# id    98000.0  48999.500000  28290.307527  0.000000  24499.750000
# f_00  98000.0      0.001220      1.002801 -4.732235     -0.675226
# f_01  98000.0      0.005580      1.000742 -4.202795     -0.670985
# f_02  98000.0     -0.001042      1.001373 -4.377021     -0.672779
# f_03  98000.0     -0.000700      1.000422 -4.010826     -0.672540
# f_04  98000.0     -0.003522      1.003061 -4.535903     -0.682510
# f_05  98000.0     -0.001612      1.000532 -4.300767     -0.675066
# f_06  98000.0     -0.003042      0.997434 -4.894525     -0.680421
# f_07  98000.0      5.545918      3.691840  0.000000      3.000000
# f_08  98000.0      6.763061      4.152348  0.000000      4.000000
# f_09  98000.0      8.193163      5.904919  0.000000      4.000000
# f_10  98000.0      8.057878      4.700226  0.000000      5.000000
# f_11  98000.0      8.084990      4.197106  0.000000      5.000000
# f_12  98000.0      7.076388      4.433308  0.000000      4.000000
# f_13  98000.0      6.286102      4.120077  0.000000      3.000000
# f_14  98000.0      0.003413      0.998940 -4.377021     -0.671810
# f_15  98000.0     -0.002639      1.001096 -4.535903     -0.677757
# f_16  98000.0      0.005404      1.003277 -4.182233     -0.671055
# f_17  98000.0      0.001656      1.001258 -4.468930     -0.672635
# f_18  98000.0     -0.005399      0.995965 -4.149688     -0.680243
# f_19  98000.0     -0.004513      1.004372 -4.894525     -0.678773
# f_20  98000.0     -0.000515      1.002962 -4.732235     -0.679777
# f_21  98000.0     -0.001670      0.999703 -4.438130     -0.675147
# f_22  98000.0     -0.038752      1.477858 -6.873999     -1.022964
# f_23  98000.0     -0.220002      1.494836 -8.234305     -1.203204
# f_24  98000.0      0.166434      1.543014 -7.792363     -0.903385
# f_25  98000.0     -0.064309      1.576086 -6.593842     -1.128966
# f_26  98000.0     -0.062540      1.428055 -7.375719     -0.975680
# f_27  98000.0      0.098472      1.305407 -7.335556     -0.746489
# f_28  98000.0     -0.230910      1.528476 -6.954151     -1.262606
#
#                50%           75%           max
# id    48999.500000  73499.250000  97999.000000
# f_00      0.002022      0.677271      4.490521
# f_01      0.006650      0.677746      4.324974
# f_02     -0.000324      0.677086      4.560247
# f_03     -0.003185      0.672097      4.399373
# f_04     -0.003307      0.677589      4.050549
# f_05      0.001024      0.673344      4.710316
# f_06     -0.002053      0.668112      3.998595
# f_07      5.000000      8.000000     32.000000
# f_08      6.000000      9.000000     30.000000
# f_09      7.000000     11.000000     44.000000
# f_10      7.000000     11.000000     36.000000
# f_11      8.000000     11.000000     28.000000
# f_12      6.000000     10.000000     38.000000
# f_13      6.000000      9.000000     30.000000
# f_14      0.003536      0.678679      4.490521
# f_15     -0.004299      0.673859      4.270708
# f_16      0.006535      0.680903      4.157538
# f_17      0.001663      0.673174      4.230849
# f_18     -0.001574      0.666996      4.710316
# f_19     -0.000587      0.672149      4.560247
# f_20     -0.000806      0.675437      4.399373
# f_21      0.000819      0.676881      4.135419
# f_22     -0.056687      0.930158      6.517721
# f_23     -0.219046      0.764690      6.054831
# f_24      0.167074      1.217432      7.527271
# f_25     -0.099221      0.987684      7.544731
# f_26     -0.070852      0.843212      7.005608
# f_27      0.082230      0.925306      7.205971
# f_28     -0.271319      0.770516      6.977150

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.heatmap(dataset.corr(), annot=True, fmt='.2f')
plt.show()

# %%
def evaluation(X, y):
    return [round(silhouette_score(X,y),4),
            round(calinski_harabasz_score(X,y),4),
            round(davies_bouldin_score(X,y),4)]

# %%
## chose important feature
best_features = [f'f_{i:02d}' for i in list(range(7, 14)) + list(range(22,29))]
dataset = dataset[best_features]

# %%
sns.set(rc={'figure.figsize':(20,16)})
sns.heatmap(dataset.corr(), annot=True, fmt='.2f')
plt.show()

# %%
## out_liers
def show_outlier(df):
    
    for clo in df.columns:
        q1 = df[col].quantile(0.25)
        q2 = df[col].quantile(0.75)
        iqr = q3-q1
        low_tail = q1 - 2 * iqr
        upper_tail = q3 + 2 *iqr
        
show_outlier(dataset)
# Out:
# f_07
# f_08
# f_09
# f_10
# f_11
# f_12
# f_13
# f_22
# f_23
# f_24
# f_25
# f_26
# f_27
# f_28

# %%
def test_model(Model, X):
    sc = StandardScaler()
    X_sc = sc.fit_transform(X)
    vis_model = KElbowVisualizer(Model, k=(4,12))
    vis_model.fit(X_sc)
    vis_model.show()
test_model(KMeans(random_state = RAND),dataset)

# %%
def test_model_KMeans(Model,X):
    Scaler = [('None', False), ('MinMax',MinMaxScaler()),('Standard',StandardScaler()),('PowerTransformer', PowerTransformer())]
    
    for scaler in Scaler:
        X_sc = X.copy()
        if scaler[0] != 'None':
            sc = scaler[1]
            X_sc = sc.fit_transform(X_sc)
        print(scaler[0], end = '')
        
        model = Model
        model.fit(X_sc)
        y_pred = model.labels_
        metrics = evaluation(X, y_pred)
        print(metrics)
test_model_KMeans(KMeans(n_clusters=7, random_state = RAND), dataset)
# Out:
# None[0.1247, 13124.3815, 1.9036]
# MinMax[0.1226, 12363.4212, 1.8894]
# Standard[0.0696, 9430.6267, 3.261]
# PowerTransformer[0.0681, 9300.8848, 2.4986]

# %%
df_pred = pd.read_csv('sample_submission.csv')
df_pred.head()
# Out:
#    Id  Predicted
# 0   0          0
# 1   1          0
# 2   2          0
# 3   3          0
# 4   4          0

# %%
def gen_res(Model, X):
    sc = StandardScaler()
    X_sc = sc.fit_transform(X)
    model = Model
    Model.fit(X_sc)
    y_pred = model.labels_
    metrics = evaluation(X_sc, y_pred)
    print(metrics)
    return y_pred
res_Kmean = gen_res(KMeans(n_clusters = 7, random_state = RAND), dataset)
# Out:
# [0.0747, 5627.6498, 2.5488]

# %%
df_pred['Predicted'] = res_Kmean
df_pred.to_csv('res_KMeans.csv', index=False)

# %%
df_pred.head()
# Out:
#    Id  Predicted
# 0   0          1
# 1   1          0
# 2   2          5
# 3   3          2
# 4   4          0

# %% [markdown]
# # Gaussian Mixture models

# %%
def gen_GMM(Model, X):
    sc = PowerTransformer()
    X_sc = sc.fit_transform(X)
    model = Model
    model.fit(X_sc)
    y_pred = model.predict(X_sc)
    metrics = evaluation(X, y_pred)
    print(metrics)
    return y_pred
res_GMM = gen_GMM(GaussianMixture(n_components = 7, random_state=RAND, max_iter = 300), dataset)
df_pred['Predicted'] = res_GMM
df_pred.to_csv('res_GMM.csv', index=False)
df_pred.head()
# Out:
# [0.055, 8459.4168, 2.9469]
#    Id  Predicted
# 0   0          6
# 1   1          3
# 2   2          6
# 3   3          1
# 4   4          4

# %%
# last gmm [0.0411, 3972.3638, 3.7426]

# %% [markdown]
# ## SOM

# %%
def gen_SOM(Model, X):
    sc = StandardScaler()
    X_sc = sc.fit_transform(X)
    model = Model
    model.fit(X_sc)
    y_pred = model.predict(X_sc)
    metrics = evaluation(X, y_pred)
    print(metrics)
    return y_pred

res_SOM = gen_SOM(SOM(m=7,n=1, random_state = RAND, dim=len(dataset.columns),), dataset)
df_pred['Predicted'] = res_SOM
df_pred.to_csv('res_SOM.csv', index=False)
df_pred.head()
# Out:
# [0.0202, 6520.6509, 3.4145]
#    Id  Predicted
# 0   0          0
# 1   1          5
# 2   2          0
# 3   3          3
# 4   4          5

# %%
## clear oulier
datasetnew = dataset.copy()
datasetnew.head()
# Out:
#    f_07  f_08  f_09  f_10  f_11  f_12  f_13      f_22      f_23      f_24  \
# 0     2    13    14     5    13     6     6 -1.090369  1.142641 -0.884274
# 1     2     3     6     4     6    16     9 -0.839474  0.459685  1.759412
# 2     5    11     5     8     9     3    11  3.267116 -0.088322 -2.168635
# 3     6     2    13     8     9     6     4  1.036631 -2.041828  1.440490
# 4     8     7     5     3     1    13    11  0.284326 -2.438365  1.473930
#
#        f_25      f_26      f_27      f_28
# 0  1.137896  1.309073  1.463002  0.813527
# 1 -0.275422 -0.852168  0.562457 -2.680541
# 2 -0.974989  1.335763 -1.110655 -3.630723
# 3 -1.900191 -0.630771 -0.050641  0.238333
# 4 -1.044684  1.602686 -0.405263 -1.987263

# %%
df_pred['Predicted'].unique()
# Out:
# array([0, 5, 3, 2, 6, 1, 8, 4, 7], dtype=int64)
